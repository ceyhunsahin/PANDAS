# %%
'''
axes = bir tane tek plotu temsil eder, burdaki axis degil :), bir plot olayidir
figure : bir veya birden fazla plot olabilir icinde, sayfanin kendisi figuredur
canvas : 

2 yontemle yapilir, functional, oo olarak
func lar plt ile import edilir,
oo lar, fig, ax li olur
'''
# Out:
# '\naxes = bir tane tek plotu temsil eder, burdaki axis degil :), bir plot olayidir\nfigure : bir veya birden fazla plot olabilir icinde, sayfanin kendisi figuredur\ncanvas : \n\n2 yontemle yapilir, functional, oo olarak\nfunc lar plt ile import edilir,\noo lar, fig, ax li olur\n'

# %%
import matplotlib.pyplot as plt

# %%
age = [25,27,29,31,33,35,37,39,41,43,45]
salary = [38496,42000,46752,49320,53325,56000,62652,64125,67256,68563,71752]

# %%
plt.plot(age, salary)
plt.show()

# %%
plt.plot(age, salary)
plt.xlabel("age")
plt.ylabel("Salary")
plt.title("Salary by Age")
# Out:
# Text(0.5, 1.0, 'Salary by Age')

# %%
salary_2 = [45496,48000,53752,57320,63325,65000,70652,70650,71256,75563,83752]

# %%
'''' tek figure tek axes'''

plt.plot(age, salary)
plt.plot(age, salary_2)
plt.xlabel("age")
plt.ylabel("Salary")
plt.title("Salary by Age")
# Out:
# Text(0.5, 1.0, 'Salary by Age')

# %%
""" label ile egrilerin hangisi ne onu goterir ve legend() ile yapmaliyiz"""
plt.plot(age, salary, label = "salary")
plt.plot(age, salary_2, label = "salary_2")
plt.xlabel("age")
plt.ylabel("Salary")
plt.title("Salary by Age")
plt.legend()

# %%
'''2 satir 1 sutun olsun 1. cisini ciziyorum
plt.tight_layout() ekrana sikistirmak icin kullanilir'''
plt.subplot(2,1,1)
plt.plot(age, salary, 'r')
plt.subplot(2,1,2)
plt.plot(age, salary_2, 'b')
plt.tight_layout();

# %%
plt.subplot(2,2,1)
plt.plot(age, salary, 'r')
plt.subplot(2,2,2)
plt.plot(age, salary, 'r')
plt.subplot(2,2,3)
plt.plot(age, salary_2, 'b')
plt.subplot(2,2,4)
plt.plot(age, salary_2, 'b')
plt.tight_layout();

# %%
plt.subplot(2,3,1)
plt.plot(age, salary, 'r')
plt.subplot(2,3,2)
plt.plot(age, salary, 'b')
plt.subplot(2,3,3)
plt.plot(age, salary_2, 'b')
plt.subplot(2,3,4)
plt.plot(age, salary_2, 'p')
plt.subplot(2,3,5)
plt.plot(age, salary, 'g')
plt.subplot(2,3,6)
plt.plot(age, salary_2, 'y')

plt.tight_layout();

# %%
plt.plot( salary, 'r')

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(zip(age, salary, salary_2)), columns = ["age", "salary", "salary_2"])

# %%
df
# Out:
#     age  salary  salary_2
# 0    25   38496     45496
# 1    27   42000     48000
# 2    29   46752     53752
# 3    31   49320     57320
# 4    33   53325     63325
# 5    35   56000     65000
# 6    37   62652     70652
# 7    39   64125     70650
# 8    41   67256     71256
# 9    43   68563     75563
# 10   45   71752     83752

# %%
df.salary
# Out:
# 0     38496
# 1     42000
# 2     46752
# 3     49320
# 4     53325
# 5     56000
# 6     62652
# 7     64125
# 8     67256
# 9     68563
# 10    71752
# Name: salary, dtype: int64

# %%
plt.plot(df["age"],df["salary"]) # important

# %%
plt.plot(df.salary)

# %%
''' OO method cizimi'''
# Out:
# ' OO method cizimi'

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8]) ### sol alt yukseklik , alt sol mesafe , genislik, yukseklik
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8]) ### sol alt yukseklik , alt sol mesafe , genislik, yukseklik
ax.plot(age, salary, 'r') # tek axes li bir figure oldu

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8]) ### sol alt yukseklik , alt sol mesafe , genislik, yukseklik
ax.plot(age, salary, 'r') # tek axes li bir figure oldu 
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_title("Salary by Age")
# Out:
# Text(0.5, 1.0, 'Salary by Age')

# %%
''' manuel axes ler ekledik'''

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8]) ### sol alt yukseklik , alt sol mesafe , genislik, yukseklik
ax2 = fig.add_axes([1.1,0.3,0.4,0.4]) ### sol alt yukseklik , alt sol mesafe , genislik, yukseklik
ax1.plot(age, salary, 'r') # tek axes li bir figure oldu 
ax1.set_xlabel("Age")
ax1.set_ylabel("Salary")
ax1.set_title("Salary by Age")

ax2.plot(age, salary_2, 'b') # tek axes li bir figure oldu 
ax2.set_xlabel("Age")
ax2.set_ylabel("Salary_2")
ax2.set_title("Salary_2 by Age")
# Out:
# Text(0.5, 1.0, 'Salary_2 by Age')

# %%
'''  adding axes automaticly --- doldurma
<<<<subplots>>>> DIKKAT!!!!'''

fig,ax = plt.subplots()
ax.plot(age, salary, 'r') # tek axes li bir figure oldu 
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_title("Salary by Age")

plt.tight_layout()

# %%
''' Subplots with OOP '''
# Out:
# ' Subplots with OOP '

# %%
fig, ax = plt.subplots(2,1)
#cfig, ax = plt.subplots(nrows = 2, ncols = 1)
ax[0].plot(age, salary, 'r') # tek axes li bir figure oldu 
ax[0].set_title("first plot")
ax[1].plot(age, salary_2, 'b') # tek axes li bir figure oldu 
ax[1].set_title("second plot")
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
fig, ax = plt.subplots(1,2)
#cfig, ax = plt.subplots(nrows = 2, ncols = 1)
ax[0].plot(age, salary, 'r') # tek axes li bir figure oldu 
ax[0].set_title("first plot")
ax[1].plot(age, salary_2, 'b') # tek axes li bir figure oldu 
ax[1].set_title("second plot")
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
fig, ax = plt.subplots(1,2)
#cfig, ax = plt.subplots(nrows = 2, ncols = 1)
a=ax[0].plot(age, salary, 'r') # tek axes li bir figure oldu 
ax[0].set_title("first plot")
b=ax[1].plot(age, salary_2, 'b') # tek axes li bir figure oldu 
ax[1].set_title("second plot")
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button, RadioButtons

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
t = np.arange(0.0, 1.0, 0.01)
a0 = 4
f0 = 3
delta_f = 2.0
s = a0 * np.sin(2 * np.pi * f0 * t)
l, = plt.plot(t, s, lw=2)
ax.margins(x=0)

axcolor = 'lightgoldenrodyellow'
axfreq = plt.axes([0.25, 0.1, 0.65, 0.03], facecolor=axcolor)
axamp = plt.axes([0.25, 0.15, 0.65, 0.03], facecolor=axcolor)

sfreq = Slider(axfreq, 'Freq', 0.1, 30.0, valinit=f0, valstep=delta_f)
samp = Slider(axamp, 'Amp', 0.1, 10.0, valinit=a0)


def update(val):
    amp = samp.val
    freq = sfreq.val
    l.set_ydata(amp*np.sin(2*np.pi*freq*t))
    fig.canvas.draw_idle()


sfreq.on_changed(update)
samp.on_changed(update)

resetax = plt.axes([0.8, 0.025, 0.1, 0.04])
button = Button(resetax, 'Reset', color=axcolor, hovercolor='0.975')


def reset(event):
    sfreq.reset()
    samp.reset()
button.on_clicked(reset)

rax = plt.axes([0.025, 0.5, 0.15, 0.15], facecolor=axcolor)
radio = RadioButtons(rax, ('red', 'blue', 'green'), active=0)


def colorfunc(label):
    l.set_color(label)
    fig.canvas.draw_idle()
radio.on_clicked(colorfunc)

# Initialize plot with correct initial active value
colorfunc(radio.value_selected)

plt.show()

# %%
''' figsize(6,3) 6 en , 3 boy diye aciklanir'''
# Out:
# ' figsize(6,3) 6 en , 3 boy diye aciklanir'

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))
a=ax[0].plot(age, salary, 'r') # tek axes li bir figure oldu 
ax[0].set_title("first plot")
b=ax[1].plot(age, salary_2, 'b') # tek axes li bir figure oldu 
ax[1].set_title("second plot")
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
fig = plt.figure(figsize = (6,3)) # bu her turlu calisir

# %%
fig, ax = plt.subplots(figsize=(8,4))
a=ax.plot(age, salary, 'r') # tek axes li bir figure oldu 
ax.set_title("first plot")
# Out:
# Text(0.5, 1.0, 'first plot')

# %%
df
# Out:
#     age  salary  salary_2
# 0    25   38496     45496
# 1    27   42000     48000
# 2    29   46752     53752
# 3    31   49320     57320
# 4    33   53325     63325
# 5    35   56000     65000
# 6    37   62652     70652
# 7    39   64125     70650
# 8    41   67256     71256
# 9    43   68563     75563
# 10   45   71752     83752

# %%
''' savings figure'''
# Out:
# ' savings figure'

# %%
fig.savefig("myplot.pdf")

# %%
fig.savefig("myplot.pdf", dpi = 100). # dpi deyince oransal buyume olur
# Out:
#   File "<ipython-input-72-045f86f5c078>", line 1
#     fig.savefig("myplot.pdf", dpi = 100). # dpi deyince oransal buyume olur
#                                           ^
# SyntaxError: invalid syntax

# %%
'''Legends labels and titles'''
# Out:
# 'Legends labels and titles'

# %%
plt.plot(age, salary, label = "salary")
plt.plot(age, salary_2, label = "salary_2")
plt.xlabel("age")
plt.ylabel("Salary")
plt.title("Salary by Age")
plt.legend(loc = "best")
plt.legend(loc = 8)
plt.tight_layout(); # ; ile gereksiz bilgiler gider

# %%
''' setting colors, linewidths and linetypes'''
# Out:
# ' setting colors, linewidths and linetypes'

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = '-')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = ':')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = '-.')
# ls'e --, -, -., : bunlar konulabilir

# %%
''' marker var'''
# Out:
# ' marker var'

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = '-.', marker = "o");

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = '-.', marker = "o", markersize = 10); # markersize : marker boyutu

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = '-.', marker = "o", markersize = 10, markerfacecolor = "g") # markerfacecolor, markerin icini doldurur

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = '-.', marker = "o", markersize = 10, markerfacecolor = "g", alpha = 0.5) # alpha=. transparent goruntu

# %%
'''plot range bir yere focuslamak istersek,'''
# Out:
# 'plot range bir yere focuslamak istersek,'

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary) 
ax.set_xlim([30,40])
# Out:
# (30.0, 40.0)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary) 
ax.set_ylim([45000,65000])
# Out:
# (45000.0, 65000.0)

# %%
''' adding vertical-horizontal lines'''
# Out:
# ' adding vertical-horizontal lines'

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = ' ', marker = "o", markersize = 10, markerfacecolor = "g", alpha = 0.5);
# mesela 35 yasa cizgi ciz demek istiyoruz
ax.axvline(x = 30, color = 'green', ls = "--")
ax.axvline(x = 40, color = 'green', ls = "--")

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary, 'r',lw = 3, ls = ' ', marker = "o", markersize = 10, markerfacecolor = "g", alpha = 0.5);
# mesela 35 yasa cizgi ciz demek istiyoruz
ax.axvline(x = 35, color = 'green', ls = "--")
ax.axhline(y = 60000, color = 'green', ls = "--")

# %%
'''Special Charts,
BAR CHARTS: 1 tarafta kategorik olacak bir yandan da sayilari olacak '''
# Out:
# 'Special Charts,\nBAR CHARTS: 1 tarafta kategorik olacak bir yandan da sayilari olacak '

# %%
''' bar plot'''
# Out:
# ' bar plot'

# %%
country = ['uk','usa','fr', 'ger','nor']
pci = [40000,50000,38000,55000,80000]

# %%
pci = sorted(pci)

# %%
fig,ax = plt.subplots()
ax.bar(country,pci);

# %%
fig,ax = plt.subplots()
ax.bar([0,1,2,3,4],pci); # x = numerik degerlerde olabilir

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5'] # yukaridaki ulkeler gibi
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x) # x eksenindeki genisligi belirtmis
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0,2),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
''' TODO SAME PLOT WITH PANDAS '''
# Out:
# ' TODO SAME PLOT WITH PANDAS '

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5'] # yukaridaki ulkeler gibi
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x) # x eksenindeki genisligi belirtmis
ax.set_xticklabels(labels)
ax.legend()

# %%
ax= df.plot.bar(rot = 0, figsize=(9,6))
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x) # x eksenindeki genisligi belirtmis
ax.set_xticklabels(labels)
ax.legend()

# %%
ax= df.plot.bar(rot = 0, figsize=(9,6))
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x) # x eksenindeki genisligi belirtmis
ax.set_xticklabels(labels)
ax.axhline(y=30000, color = 'blue', ls = '--')
ax.legend()
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.04,p.get_height()+1))

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5'] # yukaridaki ulkeler gibi
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax.bar(labels, men_means, width, label='Men')
ax.bar(labels, women_means, width, bottom = men_means, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

# %%
df.plot.bar(stacked=True, rot=0);

# %%
df.plot.barh(stacked=True, rot=0);

# %%
slices = [59219,55466,47544,36443,35917]
langs = ["JavaScript", "HTML/CSS", "SQL", "Python", "Java"]

# %%
fig,ax = plt.subplots(figsize=(8,4))
ax.plot(slices, langs)

# %%
explode=(0.2,0,0,0,0)
fig,ax = plt.subplots(figsize=(8,6))

ax.pie(slices, explode= explode, labels = langs, autopct = '%1.1f%%', shadow = False, startangle = 110)
ax.axis('equal');
fig.savefig("pie chart.jpeg", dpi=100)

# %%
''' HISTOGRAM'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("hist_data.csv")

data.head()

# %%
data.Age.shape
data.Age.nunique() # kac tane yasi farkli olan var

# %%
ages = data['Age']

# %%
fig, ax = plt.subplots()
ax.hist(ages, bins = 10) # histogram cizimi basittir, hemen bu sekilde cizilir
''' bins = '''

# %%
fig, ax = plt.subplots(1,2, figsize= (12,6))
ax[0].hist(data['Age'], bins = 10) # histogram cizimi basittir, hemen bu sekilde cizilir
ax[1].boxplot(data['Age'])
# yanyana bu sekilde de cizilebilir, ister ayrintili ister ages yazabiliriz
ax[0].axvline(mean, color = 'red', ls = '--')
ax.axhline(median, color = 'red', ls = '--')
